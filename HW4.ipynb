# %%
import re
import os

import pandas as pd

# %%
def parse_profiler_results(filename):
    with open(filename, 'r') as f:
        results = f.readlines()

    total_pattern = '[0-9.]+'
    total_expr = re.compile(total_pattern)

    total_line = results[0]
    total_stats = (total_func_calls, total_prim_calls, total_time) = \
        re.findall(total_expr, total_line)

    col_names = results[4]
    col_names = col_names.strip().split('  ')
    col_names = col_names[:-1] + col_names[-1].split(' ')

    data_lines = results[5:-2]
    data_lines = [line.strip() for line in data_lines]
    data_lines = [line.split('   ') for line in data_lines]
    data_lines = [[item.strip() for item in line]  for line in data_lines]
    data_lines = [line[:-1] + line[-1].split(' ', 1) for line in data_lines]

    df = pd.DataFrame(data_lines, columns=col_names)
    df = df.loc[:,~df.columns.duplicated()]
    df[['func_calls', 'prim_calls']] = df['ncalls'].str.split('/', expand=True)
    num_cols = ['func_calls', 'prim_calls', 'tottime', 'percall', 'cumtime']
    df[num_cols] = df[num_cols].astype(float)
    df['prim_calls'] = df['prim_calls'].fillna(0)
    df['filename:lineno(function)'] = df['filename:lineno(function)'].str.replace('/home/nicholas','')
    df['filename:lineno(function)'] = df['filename:lineno(function)'].str.replace('/Desktop/CARBONE-NICHOLAS','')
    
    return total_stats, df

# %%
line_break = '--------------------------------'
func_s = '({}) function: {}'
stats_s = 'function calls: {:.0f} | primitive calls: {:.0f} | {}: {:.2f}'
total_s = 'function calls: {} | primitive calls: {} | total runtime: {}'
keys = ['percall', 'tottime', 'cumtime']

def print_results(alias, total_stats, results):
    print('Printing results for {} code.'.format(alias))
    print(line_break)
    print(line_break + '\n')
    print('Overall stats')
    print(line_break)
    print(line_break)
    print(total_s.format(*total_stats))
    print(line_break)
    print(line_break + '\n')
    
    for key in keys:
        print('Results sorted by {}.'.format(key))
        print(line_break)
        print(line_break)
        
        i = 0
        for row in results.sort_values(key, ascending=False).iterrows():
            row = row[1]
            func_s_row = func_s.format(
                i+1,
                row['filename:lineno(function)'],
            )

            stats_s_row = stats_s.format(
                row['func_calls'],
                row['prim_calls'],
                key,
                row[key]
            )
            print(func_s_row)
            print(line_break)
            print(stats_s_row)

            i += 1
            if i < 10:
                print('')
            else:
                break

        print(line_break)
        print(line_break + '\n')

# %%
old_total_stats, old_results = parse_profiler_results('profiler_results_old.txt')
new_total_stats, new_results = parse_profiler_results('profiler_results_new.txt')

# %%
print_results('old', old_total_stats, old_results)
# Out:
# Printing results for old code.
# --------------------------------
# --------------------------------
#
# Overall stats
# --------------------------------
# --------------------------------
# function calls: 3345725 | primitive calls: 3252870 | total runtime: 38.447
# --------------------------------
# --------------------------------
#
# Results sorted by percall.
# --------------------------------
# --------------------------------
# (1) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/policy/sample_batch.py:213(shuffle)
# --------------------------------
# function calls: 30 | primitive calls: 0 | percall: 0.36
#
# (2) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/utils/sgd.py:102(do_minibatch_sgd)
# --------------------------------
# function calls: 1 | primitive calls: 0 | percall: 0.12
#
# (3) function: /miniconda3/envs/fin-env/lib/python3.8/json/decoder.py:343(raw_decode)
# --------------------------------
# function calls: 2 | primitive calls: 0 | percall: 0.02
#
# (4) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/evaluation/sampler.py:452(_env_runner)
# --------------------------------
# function calls: 2 | primitive calls: 0 | percall: 0.01
#
# (5) function: {method 'run_backward' of 'torch._C._EngineBase' objects}
# --------------------------------
# function calls: 150 | primitive calls: 0 | percall: 0.01
#
# (6) function: /market-env/market_env/envs/market_env.py:153(reset)
# --------------------------------
# function calls: 2 | primitive calls: 0 | percall: 0.00
#
# (7) function: {method 'to' of 'torch._C._TensorBase' objects}
# --------------------------------
# function calls: 12933 | primitive calls: 0 | percall: 0.00
#
# (8) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/torch/distributions/kl.py:214(_kl_categorical_categorical)
# --------------------------------
# function calls: 300 | primitive calls: 0 | percall: 0.00
#
# (9) function: {method 'clear' of 'dict' objects}
# --------------------------------
# function calls: 1 | primitive calls: 0 | percall: 0.00
#
# (10) function: {built-in method _pickle.dumps}
# --------------------------------
# function calls: 1 | primitive calls: 0 | percall: 0.00
# --------------------------------
# --------------------------------
#
# Results sorted by tottime.
# --------------------------------
# --------------------------------
# (1) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/policy/sample_batch.py:213(shuffle)
# --------------------------------
# function calls: 30 | primitive calls: 0 | tottime: 10.82
#
# (2) function: {method 'to' of 'torch._C._TensorBase' objects}
# --------------------------------
# function calls: 12933 | primitive calls: 0 | tottime: 9.86
#
# (3) function: {method 'item' of 'torch._C._TensorBase' objects}
# --------------------------------
# function calls: 482838 | primitive calls: 0 | tottime: 5.00
#
# (4) function: {built-in method numpy.array}
# --------------------------------
# function calls: 14073 | primitive calls: 0 | tottime: 1.24
#
# (5) function: /model.py:121(<listcomp>)
# --------------------------------
# function calls: 3324 | primitive calls: 0 | tottime: 1.20
#
# (6) function: /model.py:126(<listcomp>)
# --------------------------------
# function calls: 3324 | primitive calls: 0 | tottime: 1.19
#
# (7) function: {method 'run_backward' of 'torch._C._EngineBase' objects}
# --------------------------------
# function calls: 150 | primitive calls: 0 | tottime: 1.10
#
# (8) function: {built-in method stack}
# --------------------------------
# function calls: 6648 | primitive calls: 0 | tottime: 0.93
#
# (9) function: {built-in method addmm}
# --------------------------------
# function calls: 13233 | primitive calls: 0 | tottime: 0.52
#
# (10) function: {method 'unbind' of 'torch._C._TensorBase' objects}
# --------------------------------
# function calls: 6648 | primitive calls: 0 | tottime: 0.51
# --------------------------------
# --------------------------------
#
# Results sorted by cumtime.
# --------------------------------
# --------------------------------
# (1) function: /train.py:87(train)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 38.45
#
# (2) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/tune/trainable.py:185(train)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 38.44
#
# (3) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/agents/trainer.py:516(train)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 38.44
#
# (4) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/util/iter.py:782(apply_foreach)
# --------------------------------
# function calls: 16 | primitive calls: 1 | cumtime: 38.43
#
# (5) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/util/iter.py:754(__next__)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 38.43
#
# (6) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/agents/trainer_template.py:146(step)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 38.43
#
# (7) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/util/iter.py:842(apply_filter)
# --------------------------------
# function calls: 3 | primitive calls: 1 | cumtime: 38.43
#
# (8) function: {built-in method builtins.next}
# --------------------------------
# function calls: 182 | primitive calls: 3 | cumtime: 38.43
#
# (9) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/execution/train_ops.py:55(__call__)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 32.18
#
# (10) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/utils/sgd.py:102(do_minibatch_sgd)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 32.18
# --------------------------------
# --------------------------------

# %%
print_results('new', new_total_stats, new_results)
# Out:
# Printing results for new code.
# --------------------------------
# --------------------------------
#
# Overall stats
# --------------------------------
# --------------------------------
# function calls: 2898403 | primitive calls: 2799314 | total runtime: 29.046
# --------------------------------
# --------------------------------
#
# Results sorted by percall.
# --------------------------------
# --------------------------------
# (1) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/policy/sample_batch.py:213(shuffle)
# --------------------------------
# function calls: 30 | primitive calls: 0 | percall: 0.34
#
# (2) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/utils/sgd.py:102(do_minibatch_sgd)
# --------------------------------
# function calls: 1 | primitive calls: 0 | percall: 0.12
#
# (3) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/evaluation/sampler.py:452(_env_runner)
# --------------------------------
# function calls: 2 | primitive calls: 0 | percall: 0.01
#
# (4) function: /miniconda3/envs/fin-env/lib/python3.8/json/decoder.py:343(raw_decode)
# --------------------------------
# function calls: 2 | primitive calls: 0 | percall: 0.01
#
# (5) function: {method 'run_backward' of 'torch._C._EngineBase' objects}
# --------------------------------
# function calls: 150 | primitive calls: 0 | percall: 0.01
#
# (6) function: {method 'reduce' of 'numpy.ufunc' objects}
# --------------------------------
# function calls: 673 | primitive calls: 0 | percall: 0.00
#
# (7) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/torch/distributions/kl.py:214(_kl_categorical_categorical)
# --------------------------------
# function calls: 300 | primitive calls: 0 | percall: 0.00
#
# (8) function: {built-in method io.open}
# --------------------------------
# function calls: 5 | primitive calls: 0 | percall: 0.00
#
# (9) function: {built-in method _pickle.dumps}
# --------------------------------
# function calls: 1 | primitive calls: 0 | percall: 0.00
#
# (10) function: /market-env/market_env/envs/market_env.py:152(reset)
# --------------------------------
# function calls: 2 | primitive calls: 0 | percall: 0.00
# --------------------------------
# --------------------------------
#
# Results sorted by tottime.
# --------------------------------
# --------------------------------
# (1) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/policy/sample_batch.py:213(shuffle)
# --------------------------------
# function calls: 30 | primitive calls: 0 | tottime: 10.25
#
# (2) function: {method 'to' of 'torch._C._TensorBase' objects}
# --------------------------------
# function calls: 12933 | primitive calls: 0 | tottime: 7.84
#
# (3) function: /model.py:115(forward)
# --------------------------------
# function calls: 3324 | primitive calls: 0 | tottime: 1.17
#
# (4) function: {method 'reduce' of 'numpy.ufunc' objects}
# --------------------------------
# function calls: 673 | primitive calls: 0 | tottime: 1.14
#
# (5) function: {built-in method numpy.array}
# --------------------------------
# function calls: 14128 | primitive calls: 0 | tottime: 1.06
#
# (6) function: {method 'run_backward' of 'torch._C._EngineBase' objects}
# --------------------------------
# function calls: 150 | primitive calls: 0 | tottime: 1.02
#
# (7) function: {built-in method addmm}
# --------------------------------
# function calls: 13233 | primitive calls: 0 | tottime: 0.53
#
# (8) function: {method 'logsumexp' of 'torch._C._TensorBase' objects}
# --------------------------------
# function calls: 3474 | primitive calls: 0 | tottime: 0.38
#
# (9) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/models/preprocessors.py:190(write)
# --------------------------------
# function calls: 6834 | primitive calls: 0 | tottime: 0.28
#
# (10) function: {method 'type' of 'torch._C._TensorBase' objects}
# --------------------------------
# function calls: 3324 | primitive calls: 0 | tottime: 0.26
# --------------------------------
# --------------------------------
#
# Results sorted by cumtime.
# --------------------------------
# --------------------------------
# (1) function: /train.py:146(train)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 29.05
#
# (2) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/agents/trainer.py:516(train)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 29.04
#
# (3) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/tune/trainable.py:185(train)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 29.04
#
# (4) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/util/iter.py:754(__next__)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 29.02
#
# (5) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/agents/trainer_template.py:146(step)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 29.02
#
# (6) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/util/iter.py:782(apply_foreach)
# --------------------------------
# function calls: 9 | primitive calls: 1 | cumtime: 29.02
#
# (7) function: {built-in method builtins.next}
# --------------------------------
# function calls: 188 | primitive calls: 3 | cumtime: 29.02
#
# (8) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/util/iter.py:842(apply_filter)
# --------------------------------
# function calls: 2 | primitive calls: 1 | cumtime: 29.02
#
# (9) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/execution/train_ops.py:55(__call__)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 21.79
#
# (10) function: /miniconda3/envs/fin-env/lib/python3.8/site-packages/ray/rllib/utils/sgd.py:102(do_minibatch_sgd)
# --------------------------------
# function calls: 1 | primitive calls: 0 | cumtime: 21.79
# --------------------------------
# --------------------------------

# %%
list_comp_funcs = [
    '/model.py:121(<listcomp>)',
    '/model.py:126(<listcomp>)'
]

old_results.loc[old_results['filename:lineno(function)'].isin(list_comp_funcs)]
# Out:
#   ncalls  tottime  percall  cumtime  filename:lineno(function)  func_calls  \
# 4   3324    1.199      0.0    3.620  /model.py:121(<listcomp>)      3324.0
# 5   3324    1.194      0.0    3.775  /model.py:126(<listcomp>)      3324.0
#
#    prim_calls
# 4         0.0
# 5         0.0

# %% [markdown]
# Due to the highly optimized nature of libraries like PyTorch and RLLib, it can be difficult to achieve much speedup on algorithms when implemented properly. However, I compared one iteration for my model to one iteration for an implementation of a simple environment in RLLib and found a difference of approximately 28 seconds. I anticipated that my model would take a bit longer to run, given that it undergoes multiple forward passes of the model, but this seemed like a larger disparity. Therefore, I sought to identify areas of excess in my code.
#
# I was able to trim down a lot of unnecessary references to objects throughout, but, for the most part, these only marginally sped up the algorithm. I then sought to investigate individual functions and their runtime using cProfile (method contained within the profiler.py script). Many of the functions listed as consuming the most time were PyTorch functions related to backprop and largely out of my control. However, I noted two particular functions of my own that seemed to be eating up a significant amount of time:
#
# <ol>
#     <li>/model.py:121(&ltlistcomp&gt)</li>
#     <li>/model.py:126(&ltlistcomp&gt)</li>
# </ol>
#
# These are list comprehension and were shown to consume the fifth and sixth most total time spent in function call (see cell 5 - "tottime" section) in the original script. As can be seen from cell 7, they collectively consume over 7 seconds of runtime. They refer to these lines of code from my model:
#
# <ol>
#     <li>action_embeddings = torch.stack([self.action_embeddings[i,int(j.item())] for i, j in enumerate(a1_vec)])</li>
#     <li>action_mask = torch.stack([self.action_mask[i,int(j.item())] for i, j in enumerate(a1_vec)])</li>
# </ol>
#
# Initially, I implemented this as a quick solution to indexing a Torch tensor based on the values in "a1_vec" to get the code running. I was aware upon implementation that this would copy tensors, but did not expect it to result in so much added time. As I became aware of their impact on speed, I decided to rewrite them using proper indexing as follows:
#
# <ol>
#     <li>action_embeddings = self.action_embeddings[torch.arange(self.action_embeddings.size(0)), a1_vec]</li>
#     <li>action_mask = self.action_mask[torch.arange(self.action_mask.size(0)), a1_vec]</li>
# </ol>
#
# These new functions do not appear in the top 10 total time spent in function call for the new script. Cleaning these up also reduced the amount of copying that needed to be done within PyTorch's backend, which further optimized the code. Altogether, this improvement shaved off approximately 9 seconds from the runtime per training iteration, taking the original 38-second iteration down to 29 seconds, which is a speedup of approximately 24%. There is probably room for improvement elsewhere, requiring further analysis of the new cProfile results.
